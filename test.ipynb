# %%
# test_camera.py (πρόχειρο)
from camera import CameraEmotionDetector

cam = CameraEmotionDetector()
while True:
    dominant, scores = cam.read_emotion()
    print(dominant, scores)

# %%
# test_audio.py
from audio_monitor import AudioMonitor
import time

audio = AudioMonitor()
audio.start()

while True:
    print("Fatigued:", audio.is_fatigued())
    time.sleep(1)

# %%
from speech_input import record_speech
record_speech()
